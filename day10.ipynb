# %%
import cv2 as cv
import skimage as ski
import matplotlib.pyplot as plt

# %%
img=cv.imread('himani image.jpg')
cv.imshow(' ',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img
# Out:
# array([[[ 42,  71, 183],
#         [ 42,  71, 183],
#         [ 42,  71, 183],
#         ...,
#         [ 42,  65, 154],
#         [ 42,  65, 154],
#         [ 42,  67, 161]],
#
#        [[ 42,  71, 183],
#         [ 42,  71, 183],
#         [ 42,  71, 183],
#         ...,
#         [ 42,  65, 154],
#         [ 42,  65, 154],
#         [ 42,  65, 154]],
#
#        [[ 42,  71, 183],
#         [ 42,  71, 183],
#         [ 42,  71, 183],
#         ...,
#         [ 42,  65, 154],
#         [ 42,  65, 154],
#         [ 42,  65, 154]],
#
#        ...,
#
#        [[ 50,  43,  18],
#         [ 49,  42,  17],
#         [ 49,  42,  17],
#         ...,
#         [ 46,  41,  16],
#         [ 47,  42,  17],
#         [ 50,  45,  20]],
#
#        [[ 50,  43,  18],
#         [ 48,  41,  16],
#         [ 48,  41,  16],
#         ...,
#         [ 49,  44,  19],
#         [ 48,  43,  18],
#         [ 46,  41,  16]],
#
#        [[ 49,  42,  17],
#         [ 51,  44,  19],
#         [ 49,  42,  17],
# ...

# %%
img1=plt.imread('himani image.jpg')
plt.imshow(img1)
